# %%
# CONFIG!!
dataset_name = "paido_dataset" # https://phon.talkbank.org/access/Eng-NA/PaidoEnglish.html
long_audio_sub_folder = "original_long_audio_recordings"
output_data_directory_name = "original_audio_segments"
output_xlsx_file_name = "segments.xlsx"
resample_rate = 16000

# %%
import os
import pylangacq
import pandas as pd
import pathlib
import torchaudio
import torchaudio.transforms as T

# %%
input_data_directory = f"../data/{dataset_name}/{long_audio_sub_folder}"
if not os.path.exists(input_data_directory):
    raise Exception("Input directory doesn't exist.")
output_data_directory = f"../data/{dataset_name}/{output_data_directory_name}"
pathlib.Path(output_data_directory).mkdir(parents=True, exist_ok=True)
output_xlsx_file_name_path = f"{output_data_directory}/{output_xlsx_file_name}"

# %%
def get_participant(dataset_name, path_to_file):
    if dataset_name == "paido_dataset":
        return os.path.basename(path_to_file).replace(".cha", "")

# %%
segments = []
for root, dirs, files in os.walk(input_data_directory):
    for file in files:
        if file.endswith(".cha"):
            path_to_file = os.path.join(root, file)
            path_to_audio_file = path_to_file.replace(".cha", ".wav")
            
            if os.path.isfile(path_to_audio_file):
                participant = get_participant(dataset_name, path_to_file)
                waveform, sample_rate = torchaudio.load(path_to_audio_file)
                resampler = T.Resample(sample_rate, resample_rate, dtype=waveform.dtype)
                resampled_waveform = resampler(waveform)[0].unsqueeze(0)

                chat = pylangacq.read_chat(path_to_file)
                participant_details = chat.headers()[0]['Participants']['CHI']
                age = participant_details['age']
                sex = participant_details['sex']
                # print(path_to_file)
                for utterance in chat.utterances(participants="CHI"):
                    start = utterance.time_marks[0] # in milliseconds
                    end = utterance.time_marks[1] # in milliseconds
                    tokens = utterance.tokens
                    tiers = utterance.tiers
                    path_to_audio_segment_file = output_data_directory + "/" +str(participant) + "_" + str(start) + "_" + str(end) + ".wav"
                    audio_segment_waveform = resampled_waveform[:, int(start/1000*resample_rate):int(end/1000*resample_rate)]
                    torchaudio.save(path_to_audio_segment_file, audio_segment_waveform, resample_rate, encoding="PCM_S", bits_per_sample=16, format="wav")
                    #print(start)
                    #print(end)
                    text = ''
                    for token in tokens:
                        text = text + token.word
                    #print(tokens)
                    #print(text)
                    #print(tiers)
                    
                    segments.append([path_to_file, path_to_audio_file, path_to_audio_segment_file, start, end, end-start, text, participant, participant_details, age, sex, tokens, tiers])
            else:
                print("ERROR!!!")
                print(path_to_audio_file)

# %%
df = pd.DataFrame(segments, columns=["path_to_chat_file", "path_to_audio_file", "path_to_audio_segment_file", "start_in_ms", "end_in_ms", "duration_in_ms", "text", "participant", "participant_details", "age", "sex", "tokens", "tiers"])

# %%
df
# Out:
#                                        path_to_chat_file  \
# 0      ../data/paido_dataset/original_long_audio_reco...
# 1      ../data/paido_dataset/original_long_audio_reco...
# 2      ../data/paido_dataset/original_long_audio_reco...
# 3      ../data/paido_dataset/original_long_audio_reco...
# 4      ../data/paido_dataset/original_long_audio_reco...
# ...                                                  ...
# 10164  ../data/paido_dataset/original_long_audio_reco...
# 10165  ../data/paido_dataset/original_long_audio_reco...
# 10166  ../data/paido_dataset/original_long_audio_reco...
# 10167  ../data/paido_dataset/original_long_audio_reco...
# 10168  ../data/paido_dataset/original_long_audio_reco...
#
#                                       path_to_audio_file  \
# 0      ../data/paido_dataset/original_long_audio_reco...
# 1      ../data/paido_dataset/original_long_audio_reco...
# 2      ../data/paido_dataset/original_long_audio_reco...
# 3      ../data/paido_dataset/original_long_audio_reco...
# 4      ../data/paido_dataset/original_long_audio_reco...
# ...                                                  ...
# 10164  ../data/paido_dataset/original_long_audio_reco...
# 10165  ../data/paido_dataset/original_long_audio_reco...
# 10166  ../data/paido_dataset/original_long_audio_reco...
# 10167  ../data/paido_dataset/original_long_audio_reco...
# 10168  ../data/paido_dataset/original_long_audio_reco...
#
#                               path_to_audio_segment_file  start_in_ms  \
# 0      ../data/paido_dataset/original_audio_segments/...        15042
# 1      ../data/paido_dataset/original_audio_segments/...        17376
# 2      ../data/paido_dataset/original_audio_segments/...        19809
# 3      ../data/paido_dataset/original_audio_segments/...        22181
# 4      ../data/paido_dataset/original_audio_segments/...        24315
# ...                                                  ...          ...
# 10164  ../data/paido_dataset/original_audio_segments/...       376745
# 10165  ../data/paido_dataset/original_audio_segments/...       380499
# 10166  ../data/paido_dataset/original_audio_segments/...       385371
# 10167  ../data/paido_dataset/original_audio_segments/...       396869
# 10168  ../data/paido_dataset/original_audio_segments/...       405491
#
#        end_in_ms  duration_in_ms      text participant  \
# 0          15751             709    sheep.  e3bt16f212
# 1          17962             586  kicking.  e3bt16f212
# 2          20640             831    toast.  e3bt16f212
# 3          23067             886  soldier.  e3bt16f212
# 4          25198             883     dude.  e3bt16f212
# ...          ...             ...       ...         ...
# 10164     377382             637     door.  e2bt16m322
# 10165     381903            1404     door.  e2bt16m322
# 10166     386526            1155    chute.  e2bt16m322
# 10167     398095            1226     cave.  e2bt16m322
# 10168     406458             967    Cupid.  e2bt16m322
#
#                                      participant_details    age     sex  \
# 0      {'name': 'Target_Child', 'language': 'eng', 'c...  3;09.  female
# 1      {'name': 'Target_Child', 'language': 'eng', 'c...  3;09.  female
# 2      {'name': 'Target_Child', 'language': 'eng', 'c...  3;09.  female
# 3      {'name': 'Target_Child', 'language': 'eng', 'c...  3;09.  female
# 4      {'name': 'Target_Child', 'language': 'eng', 'c...  3;09.  female
# ...                                                  ...    ...     ...
# 10164  {'name': 'Target_Child', 'language': 'eng', 'c...  2;09.    male
# 10165  {'name': 'Target_Child', 'language': 'eng', 'c...  2;09.    male
# 10166  {'name': 'Target_Child', 'language': 'eng', 'c...  2;09.    male
# 10167  {'name': 'Target_Child', 'language': 'eng', 'c...  2;09.    male
# 10168  {'name': 'Target_Child', 'language': 'eng', 'c...  2;09.    male
#
#                                                   tokens  \
# 0      [Token(word='sheep', pos=None, mor=None, gra=N...
# 1      [Token(word='kicking', pos=None, mor=None, gra...
# 2      [Token(word='toast', pos=None, mor=None, gra=N...
# 3      [Token(word='soldier', pos=None, mor=None, gra...
# 4      [Token(word='dude', pos=None, mor=None, gra=No...
# ...                                                  ...
# 10164  [Token(word='door', pos=None, mor=None, gra=No...
# 10165  [Token(word='door', pos=None, mor=None, gra=No...
# 10166  [Token(word='chute', pos=None, mor=None, gra=N...
# 10167  [Token(word='cave', pos=None, mor=None, gra=No...
# 10168  [Token(word='Cupid', pos=None, mor=None, gra=N...
#
#                                                    tiers
# 0      {'CHI': 'sheep . 15042_15751', '%xwb': 'ʃip ...
# 1      {'CHI': 'kicking . 17376_17962', '%xwb': 'kʰ...
# 2      {'CHI': 'toast . 19809_20640', '%xwb': 'tʰos...
# 3      {'CHI': 'soldier . 22181_23067', '%xwb': 'so...
# 4      {'CHI': 'dude . 24315_25198', '%xwb': 'dud (...
# ...                                                  ...
# 10164  {'CHI': 'door . 376745_377382', '%xwb': 'doɹ...
# 10165  {'CHI': 'door . 380499_381903', '%xwb': 'doɹ...
# 10166  {'CHI': 'chute . 385371_386526', '%xwb': 'ʃu...
# 10167  {'CHI': 'cave . 396869_398095', '%xwb': 'kʰe...
# 10168  {'CHI': 'Cupid . 405491_406458', '%xwb': 'kʲ...
#
# [10169 rows x 13 columns]

# %%
df.to_excel(output_xlsx_file_name_path, index=False)
